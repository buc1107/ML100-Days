# %%
import os
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
from sklearn import datasets, metrics, linear_model
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
dir_data = '../data/ml100marathon'
train_app = os.path.join(dir_data, 'train_data.csv')
test_app = os.path.join(dir_data, 'test_features.csv')

# %%
df_train = pd.read_csv(train_app)
df_train.head()
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person        ...          \
# 0   46950.0           18.0                     42.0        ...
# 1   29336.0          108.0                     88.0        ...
# 2   22884.0           39.0                     13.0        ...
# 3  118134.0            NaN                      NaN        ...
# 4   35818.0          144.0                    199.0        ...
#
#    long_term_incentive      other   poi  restricted_stock  \
# 0            1617011.0   174839.0  True         2748364.0
# 1            1920000.0    22122.0  True         6843672.0
# 2                  NaN  1573324.0  True          869220.0
# 3             602671.0   907502.0  True          985032.0
# 4             375304.0      486.0  True          126027.0
#
#    restricted_stock_deferred     salary  shared_receipt_with_poi  to_messages  \
# 0                        NaN   420636.0                    864.0        905.0
# 1                        NaN  1111258.0                   2042.0       3627.0
# 2                        NaN   211844.0                     91.0        225.0
# 3                        NaN   224305.0                      NaN          NaN
# 4                        NaN   240189.0                   2188.0       2598.0
#
#    total_payments  total_stock_value
# 0        505050.0         22542539.0
# 1       8682716.0         26093672.0
# 2       2003885.0          2493616.0
# 3       2652612.0           985032.0
# 4       1639297.0           126027.0
#
# [5 rows x 22 columns]

# %%
df_test = pd.read_csv(test_app)
df_test.head()
# Out:
#                  name      bonus  deferral_payments  deferred_income  \
# 0    BELDEN TIMOTHY N  5249999.0          2144013.0       -2334434.0
# 1  BOWEN JR RAYMOND M  1350000.0                NaN           -833.0
# 2      HANNON KEVIN P  1500000.0                NaN       -3117011.0
# 3    DELAINEY DAVID W  3000000.0                NaN              NaN
# 4    CAUSEY RICHARD A  1000000.0                NaN        -235000.0
#
#    director_fees             email_address  exercised_stock_options  expenses  \
# 0            NaN      tim.belden@enron.com                 953136.0   17355.0
# 1            NaN   raymond.bowen@enron.com                      NaN   65907.0
# 2            NaN    kevin.hannon@enron.com                5538001.0   34039.0
# 3            NaN  david.delainey@enron.com                2291113.0   86174.0
# 4            NaN  richard.causey@enron.com                      NaN   30674.0
#
#    from_messages  from_poi_to_this_person        ...          loan_advances  \
# 0          484.0                    228.0        ...                    NaN
# 1           27.0                    140.0        ...                    NaN
# 2           32.0                     32.0        ...                    NaN
# 3         3069.0                     66.0        ...                    NaN
# 4           49.0                     58.0        ...                    NaN
#
#    long_term_incentive     other  restricted_stock  restricted_stock_deferred  \
# 0                  NaN  210698.0          157569.0                        NaN
# 1             974293.0    1621.0          252055.0                        NaN
# 2            1617011.0   11350.0          853064.0                        NaN
# 3            1294981.0    1661.0         1323148.0                        NaN
# 4             350000.0  307895.0         2502063.0                        NaN
#
#      salary  shared_receipt_with_poi  to_messages  total_payments  \
# 0  213999.0                   5521.0       7991.0       5501630.0
# 1  278601.0                   1593.0       1858.0       2669589.0
# 2  243293.0                   1035.0       1045.0        288682.0
# 3  365163.0                   2097.0       3093.0       4747979.0
# 4  415189.0                   1585.0       1892.0       1868758.0
#
#    total_stock_value
# 0          1110705.0
# 1           252055.0
# 2          6391065.0
# 3          3614261.0
# 4          2502063.0
#
# [5 rows x 21 columns]

# %%
# corr_about_TARGET = df_train.corr()['poi']
# df_train.corr()

# %%
# dtype_select = ['float64', 'int64']
# selected_vector = [False]*len(df_train.dtypes)
# for type_sel in dtype_select:
#     selected_vector |= (df_train.dtypes == type_sel)
# numeric_columns = list(df_train.columns[list(selected_vector)])
# print("Number of columns", len(numeric_columns))
# # 再把只有 2 值 (通常是 0,1) 的欄位去掉
# numeric_columns = list(df_train[numeric_columns].columns[list(df_train[numeric_columns].apply(lambda x:len(x.unique())!=2 ))])
# fig_num = len(numeric_columns)
# print("Number of remained columns", len(numeric_columns))

# plt.figure(figsize=(20,fig_num*3))
# index = 1
# for col in numeric_columns:
#     plt.subplot(fig_num,1,index)
#     plt.title(col)
#     df_train.boxplot(col,vert=False)
#     index += 1
# plt.show()

# %%
# plt.figure(figsize=(20,fig_num*3))
# plt.subplots_adjust(hspace=0.5)
# index = 1
# for col in numeric_columns:
#     #print(type(col),col,'correlation is ',corr_about_TARGET[col])
#     plt.subplot(fig_num,1,index)
#     plt.title(col+' corr = '+str(corr_about_TARGET[col]))
#     plt.plot(df_train[col],df_train['poi'],'.')
#     index += 1
# plt.show()

# %%
df_train['deferred_income']*=-1
df_test['deferred_income']*=-1
df_train['restricted_stock_deferred']*=-1
df_test['restricted_stock_deferred']*=-1


train_Y = df_train['poi']
test_name = df_test['name']
result_back = df_test[df_test['name']=='TOTAL']
df_train_d = df_train.drop(['director_fees','loan_advances','name', 'email_address','restricted_stock_deferred','poi'] , axis=1)
df_test_d = df_test.copy()
df_test_d[df_test_d['name'] == 'TOTAL'] = np.nan
df_test_d = df_test_d.drop(['director_fees','loan_advances','name','restricted_stock_deferred','email_address'] , axis=1)
result_back_d = result_back.drop(['director_fees','loan_advances','name','restricted_stock_deferred','email_address'] , axis=1)
print(df_train_d.values.shape)
print(df_test_d.values.shape)
df = pd.concat([df_train_d,df_test_d]).reset_index(drop=True)
print(df.values.shape)
train_num = train_Y.shape[0]
df
# Out:
# (113, 16)
# (33, 16)
# (146, 16)
#          bonus  deferral_payments  deferred_income  exercised_stock_options  \
# 0    1750000.0                NaN        3504386.0               19794175.0
# 1    5600000.0                NaN              NaN               19250000.0
# 2     200000.0                NaN           4167.0                1624396.0
# 3     800000.0                NaN              NaN                      NaN
# 4    1250000.0                NaN         262500.0                      NaN
# 5          NaN            10259.0              NaN               30766064.0
# 6          NaN                NaN              NaN                8308552.0
# 17        NaN            NaN                      NaN
# 18    22344.0            NaN                      NaN
# 19        NaN           63.0                     67.0
# 20    46145.0           41.0                      0.0
# 21    18834.0            NaN                      NaN
# 22      600.0          125.0                      0.0
# 23        NaN           13.0                     54.0
# 24        NaN           12.0                     10.0
# 25        NaN            NaN                      NaN
# 26     5774.0         1728.0                    251.0
# 27        NaN           26.0                      0.0
# 28    28164.0           14.0                     10.0
# 29    83585.0        14368.0                     41.0
# ..        ...            ...                      ...
# 116   86174.0         3069.0                     66.0
# 117   30674.0           49.0                     58.0
# 118   98849.0           27.0                     40.0
# 119   86987.0           21.0                    242.0
# 120       NaN            NaN                      NaN
# 121   96268.0           22.0                    188.0
# 122    8409.0            NaN                      NaN
# 123       NaN         1073.0                     44.0
# 124       NaN           26.0                     10.0
# 125       NaN           25.0                     39.0
# 126    2151.0            NaN                      NaN
# 127   51124.0          909.0                     64.0
# 128       NaN           16.0                      0.0
# 129   52255.0            NaN                      NaN
# 130  116335.0            NaN                      NaN
# 131  129142.0            NaN                      NaN
# 132       NaN            NaN                      NaN
# 133       NaN            NaN                      NaN
# 134   95924.0           75.0                     42.0
# 135   94299.0           29.0                     38.0
# 136       NaN            NaN                      NaN
# 137   35018.0            NaN                      NaN
# 138       NaN           15.0                     29.0
# 139       NaN           29.0                      0.0
# 140   33785.0            NaN                      NaN
# 141   38559.0           40.0                     23.0
# 142       NaN           92.0                     28.0
# 143       NaN           12.0                      0.0
# 144   57727.0            NaN                      NaN
# 145  137108.0           48.0                     58.0
#
#      from_this_person_to_poi  long_term_incentive       other  \
# 0                        4.0            1617011.0    174839.0
# 1                       30.0            1920000.0     22122.0
# 2                       14.0                  NaN   1573324.0
# 3                        NaN             602671.0    907502.0
# 4                       25.0             375304.0       486.0
# 5                        NaN                  NaN      2856.0
# 6                        NaN                  NaN    147950.0
# 7                       11.0                  NaN    101740.0
# 8                       16.0            3600000.0  10359729.0
# 9                        6.0              71023.0    200308.0
# 10                      15.0             300000.0    150458.0
# 11                      48.0                  NaN      1950.0
# 12                       NaN            1736055.0    277464.0
# 13                       NaN             304805.0    819288.0
# 14                      65.0             304805.0       152.0
# 15                       2.0             831809.0       272.0
# 16                       NaN                  NaN     76547.0
# 17                       NaN                  NaN         NaN
# 18                       NaN             275000.0       713.0
# 19                      14.0            1387399.0      3083.0
# 20                       0.0             200000.0    426629.0
# 21                       NaN             135836.0       176.0
# 22                       0.0             304805.0      1215.0
# 23                       1.0                  NaN         NaN
# 24                       0.0                  NaN         NaN
# 25                       NaN                  NaN         NaN
# 26                     194.0                  NaN     93925.0
# 27                       0.0                  NaN         NaN
# 28                       3.0                  NaN       774.0
# 29                     171.0             323466.0      4669.0
# ..                       ...                  ...         ...
# 116                    609.0            1294981.0      1661.0
# 117                     12.0             350000.0    307895.0
# 118                      1.0              69223.0      1936.0
# 119                      6.0            1617011.0   7427621.0
# 120                      NaN                  NaN         NaN
# 121                     11.0                  NaN       891.0
# 122                      NaN             156250.0    202052.0
# 123                     15.0                  NaN         NaN
# 124                      0.0                  NaN         NaN
# 125                     18.0                  NaN         NaN
# 126                      NaN                  NaN         NaN
# 127                     20.0             484000.0      7482.0
# 128                      1.0                  NaN         NaN
# 129                      NaN             415657.0      1105.0
# 130                      NaN                  NaN    465357.0
# 131                      NaN                  NaN        69.0
# 132                      NaN                  NaN         NaN
# 133                      NaN                  NaN         NaN
# 134                     37.0             374347.0    401481.0
# 135                      1.0                  NaN      1740.0
# 136                      NaN                  NaN    189583.0
# 137                      NaN                  NaN      1411.0
# 138                      7.0              75000.0       540.0
# 139                      1.0                  NaN    137864.0
# 140                      NaN                  NaN         NaN
# 141                      8.0             369721.0    425688.0
# 142                     23.0             554422.0   1852186.0
# 143                      0.0             461912.0         NaN
# 144                      NaN             175000.0      2630.0
# 145                     26.0             694862.0    297353.0
#
#      restricted_stock     salary  shared_receipt_with_poi  to_messages  \
# 0           2748364.0   420636.0                    864.0        905.0
# 1           6843672.0  1111258.0                   2042.0       3627.0
# 2            869220.0   211844.0                     91.0        225.0
# 3            985032.0   224305.0                      NaN          NaN
# 4            126027.0   240189.0                   2188.0       2598.0
# 5                 NaN        NaN                      NaN          NaN
# 6           3576206.0   158403.0                      NaN          NaN
# 7            698242.0   288542.0                   1132.0       1758.0
# 8          14761694.0  1072321.0                   2411.0       4273.0
# 9            393818.0   274975.0                    874.0        873.0
# 10          1248318.0   309946.0                   2271.0       2374.0
# 11           283649.0   249201.0                   1258.0       1328.0
# 12          1794412.0   440698.0                      NaN          NaN
# 13           441096.0   272880.0                      NaN          NaN
# 14           126027.0   201955.0                   1407.0       2902.0
# 15           189041.0   248546.0                   2326.0       2475.0
# 16           235370.0   192008.0                      NaN          NaN
# 17                NaN        NaN                      NaN          NaN
# 18           207940.0   184899.0                      NaN          NaN
# 19           360528.0   273746.0                   2672.0       2822.0
# 20           365320.0   222093.0                     73.0        266.0
# 21          2041016.0    94941.0                      NaN          NaN
# 22           189041.0   248017.0                     23.0       1088.0
# 23           934065.0        NaN                    720.0        894.0
# 24           386335.0        NaN                     58.0        764.0
# 25           264013.0        NaN                      NaN          NaN
# 26           466101.0   271442.0                   3669.0       8305.0
# 27                NaN        NaN                     12.0        653.0
# 28                NaN   221003.0                    114.0        176.0
# 29           126027.0   275101.0                    583.0       4607.0
# ..                ...        ...                      ...          ...
# 116         1323148.0   365163.0                   2097.0       3093.0
# 117         2502063.0   415189.0                   1585.0       1892.0
# 118          441096.0   211788.0                    900.0       1320.0
# 119         4188667.0  1060932.0                   2979.0       3275.0
# 120           32460.0        NaN                      NaN          NaN
# 121          315068.0   278601.0                    772.0        865.0
# 122          201483.0    76399.0                      NaN          NaN
# 123         2046079.0        NaN                   1074.0       2350.0
# 124               NaN        NaN                    739.0        952.0
# 125          405999.0        NaN                    583.0        613.0
# 126               NaN        NaN                      NaN          NaN
# 127         1787380.0   492375.0                   1401.0       2181.0
# 128           47304.0        NaN                      3.0         58.0
# 129          315068.0   210500.0                      NaN          NaN
# 130         1034346.0   174246.0                      NaN          NaN
# 131          145796.0   239671.0                      NaN          NaN
# 132          208809.0        NaN                      NaN          NaN
# 133               NaN        NaN                      NaN          NaN
# 134         1392142.0   304588.0                   1604.0       1755.0
# 135          585062.0   365788.0                    702.0        807.0
# 136               NaN        NaN                      NaN          NaN
# 137          208510.0   267093.0                      NaN          NaN
# 138          307301.0   261809.0                    196.0        312.0
# 139        -2604490.0        NaN                    463.0        523.0
# 140               NaN        NaN                      NaN          NaN
# 141          378082.0   213625.0                   1336.0       1607.0
# 142         1293424.0   428780.0                   2103.0       3187.0
# 143               NaN        NaN                     23.0        169.0
# 144          514847.0   236457.0                      NaN          NaN
# 145          558801.0   370448.0                   2228.0       2355.0
#
#      total_payments  total_stock_value
# 0          505050.0         22542539.0
# 1         8682716.0         26093672.0
# 2         2003885.0          2493616.0
# 3         2652612.0           985032.0
# 4         1639297.0           126027.0
# 5           91093.0         30766064.0
# 6          360300.0         11884758.0
# 7         1490344.0           698242.0
# 8       103559793.0         49110078.0
# 9         1272284.0           778546.0
# 10        1587421.0          1920055.0
# 11        1099100.0          1918887.0
# 12        2424083.0          1794412.0
# 13        2146973.0           877611.0
# 14        4484442.0          1729541.0
# 15        2014835.0           954354.0
# 16         900585.0           318607.0
# 17              NaN           139130.0
# 18         807956.0           207940.0
# 19        2664228.0           360528.0
# 20         911453.0          4817796.0
# 21         249787.0          7307594.0
# 22        1054637.0          1014505.0
# 23              NaN          1691366.0
# 24              NaN          1038185.0
# 25              NaN          1945360.0
# 26        3471141.0           547143.0
# 27              NaN                NaN
# 28         319941.0                NaN
# 29        1086821.0           976037.0
# ..              ...                ...
# 116       4747979.0          3614261.0
# 117       1868758.0          2502063.0
# 118       2081796.0           441096.0
# 119      17252530.0         14622185.0
# 120             NaN                NaN
# 121        875760.0          1080988.0
# 122        394475.0          4221891.0
# 123       3131860.0          7256648.0
# 124             NaN           850477.0
# 125             NaN          1832468.0
# 126          2151.0                NaN
# 127        550981.0          8831913.0
# 128             NaN            47304.0
# 129       1204583.0          2027865.0
# 130        704896.0          1034346.0
# 131        827696.0            63014.0
# 132        564348.0          1095040.0
# 133             NaN                NaN
# 134       3676340.0          2332399.0
# 135       1061827.0           585062.0
# 136        189583.0                NaN
# 137        628522.0           208510.0
# 138        477557.0                NaN
# 139      15456290.0                NaN
# 140         87410.0          1030329.0
# 141       2047593.0          1843816.0
# 142       4335388.0          3128982.0
# 143        966522.0          2218275.0
# 144        875889.0          3064208.0
# 145       4099771.0          1662855.0
#
# [146 rows x 16 columns]

# %%
def clip_outliers (in_df, col, th_low, th_high):
    out_df = in_df.copy()
    out_df[col] = in_df[col].clip(th_low,th_high)
#    for i in range(len(mask)):
#        print('i = '+str(i)+', mask['+str(i)+'] = '+str(mask[i]))
#        if mask[i] == True:
#            print('The '+str(i)+'-th entry of column: '+col+' (originally '+str(in_df.iloc[i,df_train_d.columns.get_loc(col)])+') is replaced by nan')
    return out_df

# %%
def log1p (in_df, col):
    out_df = in_df.copy()
    out_df[col] = np.log1p(in_df[col])
    return out_df

# %%
df = log1p(df,'bonus')
df = log1p(df,'deferral_payments')
df = log1p(df,'deferred_income')
df = log1p(df,'exercised_stock_options')
df = log1p(df,'expenses')
df = log1p(df,'long_term_incentive')
df = log1p(df,'restricted_stock')
df = log1p(df,'salary')
df = log1p(df,'shared_receipt_with_poi')
df = log1p(df,'to_messages')
df = log1p(df,'total_payments')
df = log1p(df,'total_stock_value')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log1p
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
all_corr = df.corr()
all_corr
# Out:
#                             bonus  deferral_payments  deferred_income  \
# bonus                    1.000000           0.443479         0.350801
# deferral_payments        0.443479           1.000000         0.670075
# deferred_income          0.350801           0.670075         1.000000
# exercised_stock_options  0.323925           0.009322         0.525682
# expenses                 0.150986          -0.090183         0.055337
# from_messages            0.047630           0.425850         0.360267
# from_poi_to_this_person  0.519040           0.248186         0.206496
# from_this_person_to_poi  0.326887           0.403321         0.296334
# long_term_incentive      0.501078           0.266127         0.290381
# other                    0.288305           0.180382         0.128982
# restricted_stock         0.333991           0.232610         0.261841
# salary                   0.556509           0.228164         0.415722
# shared_receipt_with_poi  0.589623           0.266997         0.407162
# to_messages              0.558914           0.188061         0.329345
# total_payments           0.726251           0.610965         0.235983
# total_stock_value        0.344552           0.145961         0.474677
#
#                          exercised_stock_options  expenses  from_messages  \
# bonus                                   0.323925  0.150986       0.047630
# deferral_payments                       0.009322 -0.090183       0.425850
# deferred_income                         0.525682  0.055337       0.360267
# exercised_stock_options                 1.000000  0.059094       0.020490
# expenses                                0.059094  1.000000       0.123703
# from_messages                           0.020490  0.123703       1.000000
# from_poi_to_this_person                 0.172113 -0.016387       0.186708
# from_this_person_to_poi                 0.089046  0.080786       0.588687
# long_term_incentive                     0.409927 -0.027127      -0.019209
# other                                   0.367775  0.061900      -0.101686
# restricted_stock                        0.619183  0.082056      -0.059406
# salary                                 -0.003296  0.105534       0.061359
# shared_receipt_with_poi                 0.210304  0.364835       0.208688
# to_messages                             0.189144  0.212723       0.402668
# total_payments                          0.289690  0.546332       0.073614
# total_stock_value                       0.941674  0.029822       0.022436
#
#                          from_poi_to_this_person  from_this_person_to_poi  \
# bonus                                   0.519040                 0.326887
# deferral_payments                       0.248186                 0.403321
# deferred_income                         0.206496                 0.296334
# exercised_stock_options                 0.172113                 0.089046
# expenses                               -0.016387                 0.080786
# from_messages                           0.186708                 0.588687
# from_poi_to_this_person                 1.000000                 0.445063
# from_this_person_to_poi                 0.445063                 1.000000
# long_term_incentive                     0.345050                 0.177918
# other                                   0.111249                -0.110335
# restricted_stock                        0.107475                 0.093601
# salary                                  0.123332                 0.088102
# shared_receipt_with_poi                 0.534850                 0.345970
# to_messages                             0.564500                 0.464861
# total_payments                          0.292519                 0.176129
# total_stock_value                       0.149499                 0.085583
#
#                          long_term_incentive     other  restricted_stock  \
# bonus                               0.501078  0.288305          0.333991
# deferral_payments                   0.266127  0.180382          0.232610
# deferred_income                     0.290381  0.128982          0.261841
# exercised_stock_options             0.409927  0.367775          0.619183
# expenses                           -0.027127  0.061900          0.082056
# from_messages                      -0.019209 -0.101686         -0.059406
# from_poi_to_this_person             0.345050  0.111249          0.107475
# from_this_person_to_poi             0.177918 -0.110335          0.093601
# long_term_incentive                 1.000000  0.384418          0.376356
# other                               0.384418  1.000000          0.488117
# restricted_stock                    0.376356  0.488117          1.000000
# salary                              0.396191  0.191751          0.151187
# shared_receipt_with_poi             0.307631  0.118932          0.324939
# to_messages                         0.300315  0.112741          0.216889
# total_payments                      0.619226  0.563058          0.233394
# total_stock_value                   0.376522  0.409973          0.768008
#
#                            salary  shared_receipt_with_poi  to_messages  \
# bonus                    0.556509                 0.589623     0.558914
# deferral_payments        0.228164                 0.266997     0.188061
# deferred_income          0.415722                 0.407162     0.329345
# exercised_stock_options -0.003296                 0.210304     0.189144
# expenses                 0.105534                 0.364835     0.212723
# from_messages            0.061359                 0.208688     0.402668
# from_poi_to_this_person  0.123332                 0.534850     0.564500
# from_this_person_to_poi  0.088102                 0.345970     0.464861
# long_term_incentive      0.396191                 0.307631     0.300315
# other                    0.191751                 0.118932     0.112741
# restricted_stock         0.151187                 0.324939     0.216889
# salary                   1.000000                 0.203979     0.241882
# shared_receipt_with_poi  0.203979                 1.000000     0.844005
# to_messages              0.241882                 0.844005     1.000000
# total_payments           0.352075                 0.359239     0.335479
# total_stock_value        0.042319                 0.266093     0.207695
#
#                          total_payments  total_stock_value
# bonus                          0.726251           0.344552
# deferral_payments              0.610965           0.145961
# deferred_income                0.235983           0.474677
# exercised_stock_options        0.289690           0.941674
# expenses                       0.546332           0.029822
# from_messages                  0.073614           0.022436
# from_poi_to_this_person        0.292519           0.149499
# from_this_person_to_poi        0.176129           0.085583
# long_term_incentive            0.619226           0.376522
# other                          0.563058           0.409973
# restricted_stock               0.233394           0.768008
# salary                         0.352075           0.042319
# shared_receipt_with_poi        0.359239           0.266093
# to_messages                    0.335479           0.207695
# total_payments                 1.000000           0.263630
# total_stock_value              0.263630           1.000000

# %%
fig_num = 16
plt.figure(figsize=(20,fig_num*3))
plt.subplots_adjust(hspace=0.5)
index = 1
for col in df:
    plt.subplot(fig_num,1,index)
    plt.title("distribution of "+col)
    sns.distplot(df[col].dropna())
    index += 1
plt.show()

# %%
plt.figure(figsize=(15,15))
heatmap = sns.heatmap(all_corr, cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)

plt.show()

# %%
#import seaborn as sns
fig_num = 8*15 
plt.figure(figsize=(20,fig_num*3))
plt.subplots_adjust(hspace=0.5)
index = 1
for i in range(len(list(df))):
    for j in range(len(list(df))):
        if j > i:
            plt.subplot(fig_num,1,index)
            plt.title(list(df)[i]+' vs '+list(df)[j]+' corr = '+str(all_corr.iloc[i,j]))
            #sns.kdeplot(df.iloc[:,i],df.iloc[:,j])
            plt.plot(df.iloc[:,i],df.iloc[:,j],'.')
            index += 1
plt.show()

# %%
df1 = df.fillna(df.mean())
df_temp = MinMaxScaler().fit_transform(df1)
train_X = df_temp[:train_num]
test_X = df_temp[train_num:]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
estimator.fit(train_X,train_Y)
y_hat = estimator.predict(test_X)
#print(test_X)
print(y_hat)
y_prob1 = estimator.predict_proba(test_X)[:,1]
print(y_prob1)
print(df1.shape)
df1
# Out:
# 0.885375494071
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False]
# 126        7.674153          14.037766
# 127       13.219457          15.993882
# 128       13.500164          10.764371
# 129       14.001645          14.522495
# 130       13.465807          13.849281
# 131       13.626402          11.051128
# 132       13.243428          13.906302
# 133       13.500164          14.037766
# 134       15.117429          14.662408
# 135       13.875503          13.279475
# 136       12.152587          14.037766
# 137       13.351128          12.247747
# 138       13.076441          14.037766
# 139       16.553527          14.037766
# 140       11.378376          13.845390
# 141       14.532176          14.427348
# 142       15.282322          14.956219
# 143       13.781460          14.612241
# 144       13.682996          14.935300
# 145       15.226442          14.324047
#
# [146 rows x 16 columns]

# %%
# df1 = df.fillna(df.mean())
# df_temp = MinMaxScaler().fit_transform(df1)
# train_X = df_temp[:train_num]
# test_X = df_temp[train_num:]
# estimator = GradientBoostingClassifier()
# print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
# estimator.fit(train_X,train_Y)
# y_hat = estimator.predict(test_X)
# #print(test_X)
# print(y_hat)
# y_prob2 = estimator.predict_proba(test_X)[:,1]
# print(y_prob2)

# %%
# df1 = df.fillna(df.mean())
# df_temp = StandardScaler().fit_transform(df1)
# train_X = df_temp[:train_num]
# test_X = df_temp[train_num:]
# estimator = RandomForestClassifier()
# print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
# estimator.fit(train_X,train_Y)
# y_hat = estimator.predict(test_X)
# #print(test_X)
# print(y_hat)
# y_prob3 = estimator.predict_proba(test_X)[:,1]
# print(y_prob3)

# %%
y_pred_df = pd.DataFrame(data={'name':test_name.values,'poi':y_prob1})
y_pred_df.to_csv('02_17_4.csv',index=None)

# %%
y_pred_df
# Out:
#                     name       poi
# 0       BELDEN TIMOTHY N  0.055139
# 1     BOWEN JR RAYMOND M  0.278314
# 2         HANNON KEVIN P  0.292779
# 3       DELAINEY DAVID W  0.066852
# 4       CAUSEY RICHARD A  0.193842
# 5       HICKERSON GARY J  0.148911
# 6         FREVERT MARK A  0.600754
# 7            CHAN RONNIE  0.044388
# 8   DONAHUE JR JEFFREY M  0.046989
# 9      REYNOLDS LAWRENCE  0.059511
# 10      HORTON STANLEY C  0.043485
# 11         LEWIS RICHARD  0.043975
# 12    SHERRICK JEFFREY B  0.044221
# 13        MEYER JEROME J  0.043588
# 14   DERRICK JR. JAMES V  0.187362
# 15              PIRO JIM  0.077258
# 16   DETMERING TIMOTHY J  0.045326
# 17     KISHKILL JOSEPH G  0.113612
# 18        BAY FRANKLIN R  0.467892
# 19        PRENTICE JAMES  0.044068
# 20                 TOTAL  0.706331
# 21        FALLON JAMES B  0.114203
# 22            METTS MARK  0.079194
# 23         WODRASKA JOHN  0.044235
# 24   MORDAUNT KRISTINA M  0.044342
# 25      CARTER REBECCA C  0.147921
# 26      BHATNAGAR SANJAY  0.071054
# 27      WALTERS GARETH W  0.044380
# 28       BIBI PHILIPPE A  0.080188
# 29       SHERRIFF JOHN R  0.167916
# 30          GIBBS DANA R  0.042937
# 31        LINDHOLM TOD A  0.045480
# 32       MCMAHON JEFFREY  0.184833

# %%
print(X_test.shape)
print(y_pred.shape)

# %% [markdown]
# # vocabulary
# * repayment: 貸款的還款
# * loan advances: 貸款預付款
# * promissory note: 本票
# * severance: 遣散
