# %% [markdown]
# ## 作業1: Two Sigma: Using News to Predict Stock Movements
# 1. 你選的這組資料為何重要
# 答: 尋找投資的聖盃，讓AI可以實現自動化投資的夢想
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 答: 資料分為兩組。巿場資料(Market Data)的提供者是Intrinio公司，透過記錄每日的股票交易數據而來。
# 新聞資料(News Data)的提供者為Thomson Reuters。透過記錄針對股票資產發佈的新聞而來。
# 3. 蒐集而來的資料型態為何
# 答: 結構化巿場資料，提供如:開盤價，收盤價，成交量、以及當日是否列入評分...等
# 新聞資料皆轉化為結構化: 記錄時間、急迫性分類、情緒判定、提供者、同列公司、關聯性....等，皆轉化為數值或類別
# 4. 這組資料想解決的問題如何評估
# 答: 可以用分類問題來看，將結果分類為漲、平、跌三類 (使用正確率)。也可以視為迴歸問題，直接預測股價變動幅度及成交量 (使用RMSE)

# %% [markdown]
# ## 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 答: 提升業績定義為: 創造最大的總獲利額，即為最大化總收入扣除人力成本及油耗成本後的值
# 我的假設是可以找到一個最佳決策，規劃每台車子要採取定點候客或行動尋找客人，決定區域中的駕駛密度，讓每台車在載到最多客人下採取移動最短距離的方案。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 答: 每台車子載客前的行進路線，每位客人的上車地、每位客人的目的地及距離，行動尋找客人的平均效益(移動時間或距離/載客)，定點候客的的平均效率(時間/載客)，需求車型和人數，時間分佈，駕駛密度對上列值的交叉分析。蒐集資料的方法是讓每台車裝設記錄器，可以記錄上列所有資訊。客服電話也可以透過詢問上車地點及人數來獲得資料。
# 3. 蒐集而來的資料型態為何
# 答: 皆為結構化資料，從人數，地點(座標，路名，自定區塊編號)，時間，車型，距離，候客時間等，都可編列為數值或類別
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 答: 透過收集每日資料，找出駕駛行為和數據結果的關聯性，例如讓駕駛在高上車需求的地點候客，或在高需求路線上移動，得到平均時間收益，如(收入-油耗)/時間作為指標，迴歸至一個最佳決策方案。透過決定單一駕駛的決策，可以用同樣方法分析不同駕駛各別的策略以最大化總收益值。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum(np.power((y - yp),2)) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 142.830
# The Mean absolute error is 9.667
