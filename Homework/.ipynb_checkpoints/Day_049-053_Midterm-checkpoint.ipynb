# %%
import os
import matplotlib.pyplot as plt 
from sklearn import datasets, metrics, linear_model
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier, RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
dir_data = '../data/ml100marathon'
train_app = os.path.join(dir_data, 'train_data.csv')
test_app = os.path.join(dir_data, 'test_features.csv')

# %%
df_train = pd.read_csv(train_app)
df_train.head()
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person        ...          \
# ...

# %%
df_test = pd.read_csv(test_app)
df_test.head()
# Out:
#                  name      bonus  deferral_payments  deferred_income  \
# 0    BELDEN TIMOTHY N  5249999.0          2144013.0       -2334434.0
# 1  BOWEN JR RAYMOND M  1350000.0                NaN           -833.0
# 2      HANNON KEVIN P  1500000.0                NaN       -3117011.0
# 3    DELAINEY DAVID W  3000000.0                NaN              NaN
# 4    CAUSEY RICHARD A  1000000.0                NaN        -235000.0
#
#    director_fees             email_address  exercised_stock_options  expenses  \
# 0            NaN      tim.belden@enron.com                 953136.0   17355.0
# 1            NaN   raymond.bowen@enron.com                      NaN   65907.0
# 2            NaN    kevin.hannon@enron.com                5538001.0   34039.0
# 3            NaN  david.delainey@enron.com                2291113.0   86174.0
# 4            NaN  richard.causey@enron.com                      NaN   30674.0
#
#    from_messages  from_poi_to_this_person        ...          loan_advances  \
# ...

# %%
corr_about_TARGET = df_train.corr()['poi']
df_train.corr()
# Out:
#                               bonus  deferral_payments  deferred_income  \
# bonus                      1.000000           0.237136        -0.330737
# deferral_payments          0.237136           1.000000        -0.851942
# deferred_income           -0.330737          -0.851942         1.000000
# director_fees                   NaN                NaN        -0.444693
# exercised_stock_options    0.594937          -0.176132        -0.312343
# expenses                   0.021938          -0.307285         0.116174
# from_messages              0.049639           0.587327        -0.485967
# from_poi_to_this_person    0.583681           0.022899         0.048235
# from_this_person_to_poi    0.354130           0.454676        -0.237202
# loan_advances              1.000000                NaN              NaN
# long_term_incentive        0.641973          -0.182344        -0.158929
# other                      0.451920          -0.130699         0.063684
# ...

# %%
dtype_select = ['float64', 'int64']
selected_vector = [False]*len(df_train.dtypes)
for type_sel in dtype_select:
    selected_vector |= (df_train.dtypes == type_sel)
numeric_columns = list(df_train.columns[list(selected_vector)])
print("Number of columns", len(numeric_columns))
# 再把只有 2 值 (通常是 0,1) 的欄位去掉
numeric_columns = list(df_train[numeric_columns].columns[list(df_train[numeric_columns].apply(lambda x:len(x.unique())!=2 ))])
fig_num = len(numeric_columns)
print("Number of remained columns", len(numeric_columns))

plt.figure(figsize=(20,fig_num*3))
index = 1
for col in numeric_columns:
    plt.subplot(fig_num,1,index)
    plt.title(col)
    df_train.boxplot(col,vert=False)
    index += 1
plt.show()
# Out:
# Number of columns 19
# Number of remained columns 19

# %%
plt.figure(figsize=(20,fig_num*3))
plt.subplots_adjust(hspace=0.5)
index = 1
for col in numeric_columns:
    #print(type(col),col,'correlation is ',corr_about_TARGET[col])
    plt.subplot(fig_num,1,index)
    plt.title(col+' corr = '+str(corr_about_TARGET[col]))
    plt.plot(df_train[col],df_train['poi'],'.')
    index += 1
plt.show()

# %%
train_Y = df_train['poi']
test_name = df_test['name']
df_train = df_train.drop(['director_fees','loan_advances','name', 'email_address','restricted_stock_deferred','poi'] , axis=1)
df_test = df_test.drop(['director_fees','loan_advances','name','restricted_stock_deferred','email_address'] , axis=1)
print(df_train.values.shape)
print(df_test.values.shape)
df = pd.concat([df_train,df_test])
print(df.values.shape)
train_num = train_Y.shape[0]
df.head()
# Out:
# (113, 19)
# (33, 19)
# (146, 19)
#        bonus  deferral_payments  deferred_income  director_fees  \
# 0  1750000.0                NaN       -3504386.0            NaN
# 1  5600000.0                NaN              NaN            NaN
# 2   200000.0                NaN          -4167.0            NaN
# 3   800000.0                NaN              NaN            NaN
# 4  1250000.0                NaN        -262500.0            NaN
#
#    exercised_stock_options  expenses  from_messages  from_poi_to_this_person  \
# 0               19794175.0   46950.0           18.0                     42.0
# 1               19250000.0   29336.0          108.0                     88.0
# 2                1624396.0   22884.0           39.0                     13.0
# 3                      NaN  118134.0            NaN                      NaN
# 4                      NaN   35818.0          144.0                    199.0
#
#    from_this_person_to_poi  loan_advances  long_term_incentive      other  \
# ...

# %%
df1 = pd.concat([df_train,train_Y],axis=1)
df1.corr()
# Out:
#                               bonus  deferral_payments  deferred_income  \
# bonus                      1.000000           0.237136        -0.330737
# deferral_payments          0.237136           1.000000        -0.851942
# deferred_income           -0.330737          -0.851942         1.000000
# director_fees                   NaN                NaN        -0.444693
# exercised_stock_options    0.594937          -0.176132        -0.312343
# expenses                   0.021938          -0.307285         0.116174
# from_messages              0.049639           0.587327        -0.485967
# from_poi_to_this_person    0.583681           0.022899         0.048235
# from_this_person_to_poi    0.354130           0.454676        -0.237202
# loan_advances              1.000000                NaN              NaN
# long_term_incentive        0.641973          -0.182344        -0.158929
# other                      0.451920          -0.130699         0.063684
# ...

# %%
df1 = df.fillna(df.mean())
df_temp = MinMaxScaler().fit_transform(df1)
train_X = df_temp[:train_num]
test_X = df_temp[train_num:]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
estimator.fit(train_X,train_Y)
y_hat = estimator.predict(test_X)
#print(test_X)
print(y_hat)
y_prob1 = estimator.predict_proba(test_X)[:,1]
print(y_prob1)
# Out:
# 0.885375494071
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False]
# [ 0.1553374   0.13115089  0.13313733  0.09076756  0.12666725  0.12591501
#   0.16580978  0.12150794  0.13173733  0.12159048  0.12202881  0.1238476
#   0.12423398  0.12088908  0.12969662  0.12042256  0.12327641  0.12013869
#   0.12135911  0.12417203  0.46641694  0.12724522  0.12534042  0.12438928
#   0.12386621  0.11943784  0.10279335  0.12456206  0.12627735  0.1285712
#   0.1204386   0.1242953   0.13200313]

# %%
df1 = df.fillna(df.mean())
df_temp = MinMaxScaler().fit_transform(df1)
train_X = df_temp[:train_num]
test_X = df_temp[train_num:]
estimator = GradientBoostingClassifier()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
estimator.fit(train_X,train_Y)
y_hat = estimator.predict(test_X)
#print(test_X)
print(y_hat)
y_prob2 = estimator.predict_proba(test_X)[:,1]
print(y_prob2)
# Out:
# 0.822529644269
# [False False False False False False  True False False False False False
#  False False False False False False  True False  True False False False
#  False False False False False False False False False]
# [  5.74691966e-04   4.25794030e-01   1.30599013e-01   1.23919118e-03
#    3.82908699e-02   4.23054364e-03   9.96713535e-01   4.60467759e-03
#    1.23678768e-03   5.44914545e-02   1.00986459e-03   5.02105825e-04
#    8.64588740e-04   2.68306537e-03   1.33294002e-02   9.51794616e-04
#    5.63657221e-03   7.87738264e-03   9.50258485e-01   4.30337932e-04
#    9.94099182e-01   1.51887826e-03   1.60022831e-03   7.27759572e-04
#    1.69467811e-03   8.53203790e-03   1.06448475e-03   1.00601623e-03
#    3.78743223e-03   6.39352121e-02   1.05785159e-03   4.95156409e-03
#    2.27364170e-03]

# %%
df1 = df.fillna(df.mean())
df_temp = StandardScaler().fit_transform(df1)
train_X = df_temp[:train_num]
test_X = df_temp[train_num:]
estimator = RandomForestClassifier()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
estimator.fit(train_X,train_Y)
y_hat = estimator.predict(test_X)
#print(test_X)
print(y_hat)
y_prob3 = estimator.predict_proba(test_X)[:,1]
print(y_prob3)
# Out:
# 0.867588932806
# [False False  True False False False  True False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False]
# [ 0.   0.3  0.6  0.1  0.4  0.3  0.7  0.   0.   0.   0.   0.   0.   0.   0.4
#   0.1  0.   0.2  0.4  0.   0.7  0.2  0.1  0.   0.   0.3  0.1  0.   0.1  0.3
#   0.   0.   0.4]

# %%
y_pred_df = pd.DataFrame(data={'name':test_name.values,'poi':(y_prob1*0.69+y_prob2*0.59+y_prob3*0.67)/1.95})
y_pred_df.to_csv('y_pred.csv',index=None)

# %%
y_pred_df
# Out:
#                     name       poi
# 0       BELDEN TIMOTHY N  0.055139
# 1     BOWEN JR RAYMOND M  0.278314
# 2         HANNON KEVIN P  0.292779
# 3       DELAINEY DAVID W  0.066852
# 4       CAUSEY RICHARD A  0.193842
# 5       HICKERSON GARY J  0.148911
# 6         FREVERT MARK A  0.600754
# 7            CHAN RONNIE  0.044388
# 8   DONAHUE JR JEFFREY M  0.046989
# 9      REYNOLDS LAWRENCE  0.059511
# 10      HORTON STANLEY C  0.043485
# 11         LEWIS RICHARD  0.043975
# 12    SHERRICK JEFFREY B  0.044221
# 13        MEYER JEROME J  0.043588
# 14   DERRICK JR. JAMES V  0.187362
# 15              PIRO JIM  0.077258
# 16   DETMERING TIMOTHY J  0.045326
# 17     KISHKILL JOSEPH G  0.113612
# 18        BAY FRANKLIN R  0.467892
# 19        PRENTICE JAMES  0.044068
# 20                 TOTAL  0.706331
# 21        FALLON JAMES B  0.114203
# 22            METTS MARK  0.079194
# 23         WODRASKA JOHN  0.044235
# 24   MORDAUNT KRISTINA M  0.044342
# 25      CARTER REBECCA C  0.147921
# ...

# %%
print(X_test.shape)
print(y_pred.shape)

# %% [markdown]
# # vocabulary
# * repayment: 貸款的還款
# * loan advances: 貸款預付款
# * promissory note: 本票
# * severance: 遣散
